# %%
import os
import train.utils as utils

DATASET_DIR = "train/UTKFace"
gender_map = {0: 'Male', 1: 'Female'}
image_files = [f for f in os.listdir(DATASET_DIR) if f.endswith('.jpg')]

utils.plot_samples(DATASET_DIR)

# %%
utils.plot_gender_distribution(image_files)

# %% [markdown]
# # Training

# %%
DATASET_DIR = "train/UTKFace"

X, y = utils.load_dataset(DATASET_DIR, 5000)

results, y_true, y_pred, y_score = utils.nested_cv(X, y)

print()
print(results)

utils.evaluate_model(results, y_true, y_pred, y_score)

final_model, scaler = utils.retrain_final_model(X, y, results)
# Out:
# Outer Fold 1:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
#   Best params: {'C': 10, 'kernel': 'rbf'}
#   Inner CV best score: 0.8495
#   Outer fold accuracy: 0.8470
#
# Outer Fold 2:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
#   Best params: {'C': 10, 'kernel': 'rbf'}
#   Inner CV best score: 0.8512
#   Outer fold accuracy: 0.8480
#
# Outer Fold 3:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
#   Best params: {'C': 10, 'kernel': 'rbf'}
#   Inner CV best score: 0.8495
#   Outer fold accuracy: 0.8590
#
# Outer Fold 4:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
#   Best params: {'C': 10, 'kernel': 'rbf'}
#   Inner CV best score: 0.8440
#   Outer fold accuracy: 0.8610
#
# Outer Fold 5:
# Fitting 4 folds for each of 8 candidates, totalling 32 fits
#   Best params: {'C': 10, 'kernel': 'rbf'}
#   Inner CV best score: 0.8575
#   Outer fold accuracy: 0.8470
#
#    fold                 best_params  accuracy    recall  precision  f1_score  \
# 0     1  {'C': 10, 'kernel': 'rbf'}     0.847  0.845188   0.836439  0.840791
# 1     2  {'C': 10, 'kernel': 'rbf'}     0.848  0.845188   0.838174  0.841667
# 2     3  {'C': 10, 'kernel': 'rbf'}     0.859  0.849057   0.854430  0.851735
# 3     4  {'C': 10, 'kernel': 'rbf'}     0.861  0.842767   0.862661  0.852598
# 4     5  {'C': 10, 'kernel': 'rbf'}     0.847  0.834382   0.843220  0.838778
#
#               conf_matrix
# 0  [[443, 79], [74, 404]]
# 1  [[444, 78], [74, 404]]
# 2  [[454, 69], [72, 405]]
# 3  [[459, 64], [75, 402]]
# 4  [[449, 74], [79, 398]]
#
# === Evaluation Results ===
# Accuracy    : 0.85 ± 0.01
# Recall      : 0.84 ± 0.00
# Precision   : 0.85 ± 0.01
# F1 Score    : 0.85 ± 0.01
#
# Retraining final model on all data with best params: {'C': 10, 'kernel': 'rbf'}
# Scaler saved to scaler.joblib
# Final model saved to svm_gender_model.joblib
